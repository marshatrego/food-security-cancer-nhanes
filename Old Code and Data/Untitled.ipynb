# %%
%let path=/folders/myfolders/NHANES; 
libname Nhanes "&path";				
				/* To access the xpt file for the med questionnaire 
					data for 2013-2014. I found it on the sas help site. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/MCQ_H.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;

					/* To access the xpt file for the food security  
					data for 2013-2014.*/
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/FSQ_H.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;
					/* To access the xpt file for the demographic 
					data for 2013-2014. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/DEMO_H.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;

					/* To access the xpt file for the health insurance 
					data for 2013-2014. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/HIQ_H.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# body .kc { color: #ff0000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #ff0000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #ff0000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #ff0000; font-weight: bold } /* Keyword.Pseudo */
# body .kr { color: #ff0000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #ff0000; font-weight: bold } /* Keyword.Type */
# body .s { color: #111111 } /* Literal.String */
# body .na { color: #008000 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #008000 } /* Name.Class */
# body .no { color: #008000 } /* Name.Constant */
# body .nd { color: #008000 } /* Name.Decorator */
# body .ni { color: #008000 } /* Name.Entity */
# body .ne { color: #008000 } /* Name.Exception */
# body .nf { color: #008000 } /* Name.Function */
# body .nl { color: #008000 } /* Name.Label */
# body .nn { color: #008000 } /* Name.Namespace */
# body .nx { color: #008000 } /* Name.Other */
# body .py { color: #008000 } /* Name.Property */
# body .nt { color: #008000 } /* Name.Tag */
# body .nv { color: #008000 } /* Name.Variable */
# body .sb { color: #111111 } /* Literal.String.Backtick */
# body .sc { color: #111111 } /* Literal.String.Char */
# body .sd { color: #111111 } /* Literal.String.Doc */
# body .s2 { color: #111111 } /* Literal.String.Double */
# body .se { color: #111111 } /* Literal.String.Escape */
# body .sh { color: #111111 } /* Literal.String.Heredoc */
# body .si { color: #111111 } /* Literal.String.Interpol */
# body .sx { color: #111111 } /* Literal.String.Other */
# body .sr { color: #111111 } /* Literal.String.Regex */
# body .s1 { color: #111111 } /* Literal.String.Single */
# body .ss { color: #111111 } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .vc { color: #008000 } /* Name.Variable.Class */
# body .vg { color: #008000 } /* Name.Variable.Global */
# body .vi { color: #008000 } /* Name.Variable.Instance */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="s">48   ods listing close;ods html5 (id=saspy_internal) file=stdout options(bitmap_mode=&#39;inline&#39;) device=svg; ods graphics on /</span><br><span class="s">48 ! outputfmt=png;</span><br><span class="cm">NOTE: Writing HTML5(SASPY_INTERNAL) Body file: STDOUT</span><br><span class="s">49   </span><br><span class="s">50   %let path=/folders/myfolders/NHANES;</span><br><span class="s">51   libname Nhanes &quot;&amp;path&quot;;				</span><br><span class="cm">NOTE: Libref NHANES was successfully assigned as follows: </span><br><span class="cm">      Engine:        V9 </span><br><span class="cm">      Physical Name: /folders/myfolders/NHANES</span><br><span class="s">52   				/* To access the xpt file for the med questionnaire</span><br><span class="s">53   					data for 2013-2014. I found it on the sas help site. */</span><br><span class="s">54   libname sasfile &#39;/folders/myfolders/NHANES/DATA&#39;;</span><br><span class="cm">NOTE: Libref SASFILE was successfully assigned as follows: </span><br><span class="cm">      Engine:        V9 </span><br><span class="cm">      Physical Name: /folders/myfolders/NHANES/DATA</span><br><span class="s">55   libname xptfile xport &#39;/folders/myfolders/NHANES/TEMP/MCQ_H.XPT&#39; access=readonly;</span><br><span class="cm">NOTE: Libref XPTFILE was successfully assigned as follows: </span><br><span class="cm">      Engine:        XPORT </span><br><span class="cm">      Physical Name: /folders/myfolders/NHANES/TEMP/MCQ_H.XPT</span><br><span class="s">56   proc copy inlib=xptfile outlib=sasfile;</span><br><span class="s">57   run;</span><br><span class="cm">NOTE: Input library XPTFILE is sequential.</span><br><span class="cm">NOTE: Copying XPTFILE.MCQ_H to SASFILE.MCQ_H (memtype=DATA).</span><br><span class="cm">NOTE: BUFSIZE is not cloned when copying across different engines. System Option for BUFSIZE was used.</span><br><span class="cm">NOTE: There were 9770 observations read from the data set XPTFILE.MCQ_H.</span><br><span class="cm">NOTE: The data set SASFILE.MCQ_H has 9770 observations and 95 variables.</span><br><span class="cm">NOTE: PROCEDURE COPY used (Total process time):</span><br><span class="cm">      real time           0.25 seconds</span><br><span class="cm">      cpu time            0.12 seconds</span><br><span class="cm">      </span><br><span class="s">58   </span><br><span class="s">59   					/* To access the xpt file for the food security</span><br><span class="s">60   					data for 2013-2014.*/</span><br><span class="s">61   libname sasfile &#39;/folders/myfolders/NHANES/DATA&#39;;</span><br><span class="cm">NOTE: Libref SASFILE was successfully assigned as follows: </span><br><span class="cm">      Engine:        V9 </span><br><span class="cm">      Physical Name: /folders/myfolders/NHANES/DATA</span><br><span class="s">62   libname xptfile xport &#39;/folders/myfolders/NHANES/TEMP/FSQ_H.XPT&#39; access=readonly;</span><br><span class="cm">NOTE: Libref XPTFILE was successfully assigned as follows: </span><br><span class="cm">      Engine:        XPORT </span><br><span class="cm">      Physical Name: /folders/myfolders/NHANES/TEMP/FSQ_H.XPT</span><br><span class="s">63   proc copy inlib=xptfile outlib=sasfile;</span><br><span class="s">64   run;</span><br><span class="cm">NOTE: Input library XPTFILE is sequential.</span><br><span class="cm">NOTE: Copying XPTFILE.FSQ_H to SASFILE.FSQ_H (memtype=DATA).</span><br><span class="cm">NOTE: BUFSIZE is not cloned when copying across different engines. System Option for BUFSIZE was used.</span><br><span class="cm">NOTE: There were 10175 observations read from the data set XPTFILE.FSQ_H.</span><br><span class="cm">NOTE: The data set SASFILE.FSQ_H has 10175 observations and 40 variables.</span><br><span class="cm">NOTE: PROCEDURE COPY used (Total process time):</span><br><span class="cm">      real time           0.14 seconds</span><br><span class="cm">      cpu time             ...

# %%
		/***************************************************************************/
		/*Doing the same thing as above ^^^^ for 2011-2012 demo, medq, fsq, and hiq*/
		/***************************************************************************/		
			
			
			
				/* To access the xpt file for the med questionnaire 
					data for 2011-2012. I found it on the sas help site. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/MCQ_G.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;
					/* To access the xpt file for the food security  
					data for 2011-2012.*/
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/FSQ_G.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;
					/* To access the xpt file for the demographic 
					data for 2011-2012. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/DEMO_G.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;

					/* To access the xpt file for the health insurance 
					data for 2011-2012. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/HIQ_G.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;

*proc contents data=sasfile.demo_h;
*run;

# %%
  				 /*********************************************************************\
  				 /*********************************************************************\
					/*First step in merging data is to sort each of the 
					data files by sequence number.*/
proc sort data=sasfile.mcq_h;
	by seqn;
proc sort data=sasfile.fsq_h;
	by seqn;
proc sort data=sasfile.demo_h;
	by seqn;
proc sort data=sasfile.hiq_h;
	by seqn;
	
proc sort data=sasfile.mcq_g;
	by seqn;
proc sort data=sasfile.fsq_g;
	by seqn;
proc sort data=sasfile.demo_g;
	by seqn;
proc sort data=sasfile.hiq_g;
	by seqn;
run; 
					/*Use the data step to name the new dataset that 
					will contain the merged files.
					Use the merge statement to merge the data
					based on the unique identifier (seqn).*/
data sasfile.medq_fsq_4yr;
	merge sasfile.fsq_h
			sasfile.mcq_h
			sasfile.demo_h
			sasfile.hiq_h
			sasfile.fsq_g
			sasfile.mcq_g
			sasfile.demo_g
			sasfile.hiq_g;
	by seqn;
run;%let path=/folders/myfolders/NHANES; 
libname Nhanes "&path";				
				/* To access the xpt file for the med questionnaire 
					data for 2013-2014. I found it on the sas help site. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/MCQ_H.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;
					/* To access the xpt file for the food security  
					data for 2013-2014.*/
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/FSQ_H.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;
					/* To access the xpt file for the demographic 
					data for 2013-2014. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/DEMO_H.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;

					/* To access the xpt file for the health insurance 
					data for 2013-2014. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/HIQ_H.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;


		/***************************************************************************/
		/*Doing the same thing as above ^^^^ for 2011-2012 demo, medq, fsq, and hiq*/
		/***************************************************************************/		
			
			
			
				/* To access the xpt file for the med questionnaire 
					data for 2011-2012. I found it on the sas help site. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/MCQ_G.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;
					/* To access the xpt file for the food security  
					data for 2011-2012.*/
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/FSQ_G.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;
					/* To access the xpt file for the demographic 
					data for 2011-2012. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/DEMO_G.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;

					/* To access the xpt file for the health insurance 
					data for 2011-2012. */
libname sasfile '/folders/myfolders/NHANES/DATA';
libname xptfile xport '/folders/myfolders/NHANES/TEMP/HIQ_G.XPT' access=readonly;
proc copy inlib=xptfile outlib=sasfile;
run;

*proc contents data=sasfile.demo_h;
*run;

  				 /*********************************************************************\
  				 /*********************************************************************\
					/*First step in merging data is to sort each of the 
					data files by sequence number.*/
proc sort data=sasfile.mcq_h;
	by seqn;
proc sort data=sasfile.fsq_h;
	by seqn;
proc sort data=sasfile.demo_h;
	by seqn;
proc sort data=sasfile.hiq_h;
	by seqn;
	
proc sort data=sasfile.mcq_g;
	by seqn;
proc sort data=sasfile.fsq_g;
	by seqn;
proc sort data=sasfile.demo_g;
	by seqn;
proc sort data=sasfile.hiq_g;
	by seqn;
run; 
					/*Use the data step to name the new dataset that 
					will contain the merged files.
					Use the merge statement to merge the data
					based on the unique identifier (seqn).*/
data sasfile.medq_fsq_4yr;
	merge sasfile.fsq_h
			sasfile.mcq_h
			sasfile.demo_h
			sasfile.hiq_h
			sasfile.fsq_g
			sasfile.mcq_g
			sasfile.demo_g
			sasfile.hiq_g;
	by seqn;
run;
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# body .kc { color: #ff0000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #ff0000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #ff0000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #ff0000; font-weight: bold } /* Keyword.Pseudo */
# body .kr { color: #ff0000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #ff0000; font-weight: bold } /* Keyword.Type */
# body .s { color: #111111 } /* Literal.String */
# body .na { color: #008000 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #008000 } /* Name.Class */
# body .no { color: #008000 } /* Name.Constant */
# body .nd { color: #008000 } /* Name.Decorator */
# body .ni { color: #008000 } /* Name.Entity */
# body .ne { color: #008000 } /* Name.Exception */
# body .nf { color: #008000 } /* Name.Function */
# body .nl { color: #008000 } /* Name.Label */
# body .nn { color: #008000 } /* Name.Namespace */
# body .nx { color: #008000 } /* Name.Other */
# body .py { color: #008000 } /* Name.Property */
# body .nt { color: #008000 } /* Name.Tag */
# body .nv { color: #008000 } /* Name.Variable */
# body .sb { color: #111111 } /* Literal.String.Backtick */
# body .sc { color: #111111 } /* Literal.String.Char */
# body .sd { color: #111111 } /* Literal.String.Doc */
# body .s2 { color: #111111 } /* Literal.String.Double */
# body .se { color: #111111 } /* Literal.String.Escape */
# body .sh { color: #111111 } /* Literal.String.Heredoc */
# body .si { color: #111111 } /* Literal.String.Interpol */
# body .sx { color: #111111 } /* Literal.String.Other */
# body .sr { color: #111111 } /* Literal.String.Regex */
# body .s1 { color: #111111 } /* Literal.String.Single */
# body .ss { color: #111111 } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .vc { color: #008000 } /* Name.Variable.Class */
# body .vg { color: #008000 } /* Name.Variable.Global */
# body .vi { color: #008000 } /* Name.Variable.Instance */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="s">82   ods listing close;ods html5 (id=saspy_internal) file=stdout options(bitmap_mode=&#39;inline&#39;) device=svg; ods graphics on /</span><br><span class="s">82 ! outputfmt=png;</span><br><span class="cm">NOTE: Writing HTML5(SASPY_INTERNAL) Body file: STDOUT</span><br><span class="s">83   </span><br><span class="s">84   </span><br><span class="s">85   </span><br><span class="s">86   </span><br><span class="s">87   		/***************************************************************************/</span><br><span class="s">88   		/*Doing the same thing as above ^^^^ for 2011-2012 demo, medq, fsq, and hiq*/</span><br><span class="s">89   		/***************************************************************************/		</span><br><span class="s">90   			</span><br><span class="s">91   			</span><br><span class="s">92   			</span><br><span class="s">93   				/* To access the xpt file for the med questionnaire</span><br><span class="s">94   					data for 2011-2012. I found it on the sas help site. */</span><br><span class="s">95   libname sasfile &#39;/folders/myfolders/NHANES/DATA&#39;;</span><br><span class="cm">NOTE: Libref SASFILE was successfully assigned as follows: </span><br><span class="cm">      Engine:        V9 </span><br><span class="cm">      Physical Name: /folders/myfolders/NHANES/DATA</span><br><span class="s">96   libname xptfile xport &#39;/folders/myfolders/NHANES/TEMP/MCQ_G.XPT&#39; access=readonly;</span><br><span class="cm">NOTE: Libref XPTFILE was successfully assigned as follows: </span><br><span class="cm">      Engine:        XPORT </span><br><span class="cm">      Physical Name: /folders/myfolders/NHANES/TEMP/MCQ_G.XPT</span><br><span class="s">97   proc copy inlib=xptfile outlib=sasfile;</span><br><span class="s">98   run;</span><br><span class="cm">NOTE: Input library XPTFILE is sequential.</span><br><span class="cm">NOTE: Copying XPTFILE.MCQ_G to SASFILE.MCQ_G (memtype=DATA).</span><br><span class="cm">NOTE: BUFSIZE is not cloned when copying across different engines. System Option for BUFSIZE was used.</span><br><span class="cm">NOTE: There were 9364 observations read from the data set XPTFILE.MCQ_G.</span><br><span class="cm">NOTE: The data set SASFILE.MCQ_G has 9364 observations and 92 variables.</span><br><span class="cm">NOTE: PROCEDURE COPY used (Total process time):</span><br><span class="cm">      real time           0.20 seconds</span><br><span class="cm">      cpu time            0.09 seconds</span><br><span class="cm">      </span><br><span class="s">99   					/* To access the xpt file for the food security</span><br><span class="s">100  					data for 2011-2012.*/</span><br><span class="s">101  libname sasfile &#39;/folders/myfolders/NHANES/DATA&#39;;</span><br><span class="cm">NOTE: Libref SASFILE was successfully assigned as follows: </span><br><span class="cm">      Engine:        V9 </span><br><span class="cm">      Physical Name: /folders/myfolders/NHANES/DATA</span><br><span class="s">102  libname xptfile xport &#39;/folders/myfolders/NHANES/TEMP/FSQ_G.XPT&#39; access=readonly;</span><br><span class="cm">NOTE: Libref XPTFILE was successfully assigned as follows: </span><br><span class="cm">      Engine:        XPORT </span><br><span class="cm">      Physical Name: /folders/myfolders/NHANES/TEMP/FSQ_G.XPT</span><br><span class="s">103  proc copy inlib=xptfile outlib=sasfile;</span><br><span class="s">104  run;</span><br><span class="cm">NOTE: Input library XPTFILE is sequential.</span><br><span class="cm">NOTE: Copying XPTFILE.FSQ_G to SASFILE.FSQ_G (memtype=DATA).</span><br><span class="cm">NOTE: BUFSIZE is not cloned when copying across different engines. System Option for BUFSIZE was used.</span><br><span class="cm">NOTE: There were 9756 observations read from the data set XPTFILE.FSQ_G.</span><br><span class="cm">NOTE: The data set SASFILE.FSQ_G has 9756 observations and 39 variables.</span><br><span class="cm">NOTE: PROCEDURE CO ...
